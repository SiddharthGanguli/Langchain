# %%
from langchain_community.llms import Ollama
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage

# %%
model=Ollama(model='gemma:2b')

# %%
chat_History=[
    SystemMessage(content='You are a helpful Aibot your name is Sandu.')
]

# %%
while True: 
    user_input=input("You : ")
    chat_history.append(HumanMessage(content=user_input))
    if user_input.lower() in  ["quit","exit",'q','e']:
        break
    else:
        result=model.invoke(chat_history)
        chat_history.append(AIMessage(content=result.content))
        print("AI: ",result.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 8
#       6 else:
#       7     result=model.invoke(chat_history)
# ----> 8     chat_history.append(AIMessage(content=result.content))
#       9     print("AI: ",result.content)
#
# AttributeError: 'str' object has no attribute 'content'
