# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.messages import HumanMessage,SystemMessage,AIMessage
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferWindowMemory

# %%
llm=HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct",
    task="Text Generation"
)

model=ChatHuggingFace(llm=llm)

# %%
memory=ConversationBufferWindowMemory(k=3)

# %%
chain=ConversationChain(
    llm=model,
    memory=memory,
    verbose=False
)

# %%
response=chain.invoke("Hey i am Rik ganguli and i'm from Kolkata Westbengal . My pin code is 700001")

# %%
response['response']
# Out:
# "It seems like you've repeated yourself. You've already mentioned that you're Rik Ganguli from Kolkata, West Bengal, with a Pin code of 700001. I've taken note of the B.B.D. Bagh area being your location. Since you've repeated the same information, I'd love to ask: what brings you to this corner of the city today? Or perhaps you'd like to discuss something else about Kolkata or its surroundings?"

# %%
response2=chain.invoke("What is my pin code and where i'm from ? ")

# %%
response2['response']
# Out:
# "You've already told me that your Pin code is 700001, which is associated with the B.B.D. Bagh area in Kolkata, West Bengal. You also mentioned that you're from Kolkata itself. I've taken note of this information earlier in our conversation. If you'd like to confirm or reiterate, I'm happy to chat with you about it, but it seems like you've already provided the necessary details. Would you like to talk about something else, perhaps your interests or experiences in Kolkata?"
