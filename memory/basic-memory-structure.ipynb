# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.llms import Ollama
from langchain_core.prompts import PromptTemplate
from langchain.memory import ConversationBufferMemory
# it store the full conversation in the chat
from langchain_huggingface.chat_models import ChatHuggingFace
from langchain_huggingface import HuggingFaceEndpoint

# %%
llm=HuggingFaceEndpoint(
    repo_id = "meta-llama/Meta-Llama-3-8B-Instruct",
    task="Text Generation"
)

# %%
model=ChatHuggingFace(llm=llm,max_tokens=100)

# %%
model.invoke("what is the capital of india ?").content
# Out:
# 'The capital of India is New Delhi.'

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

# %%
memory=ConversationBufferMemory()
# Out:
# /var/folders/6h/lkrcqc7d0vj6gsp7yc3xwlbr0000gn/T/ipykernel_20956/2290902444.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory=ConversationBufferMemory()

# %%
ConversationChain(
    llm=model,
    memory=memory,
    verbose=True
    )
