# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import ChatHuggingFace,HuggingEndpoint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_huggingface import ChatHuggingFace,HuggingEndpoint
#
# ModuleNotFoundError: No module named 'langchain_huggingface'
