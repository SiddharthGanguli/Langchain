# %%
from langchain_community.llms import Ollama
from langchain_core.messages import HumanMessage,AIMessage,SystemMessage

from langchain_core.prompts import ChatPromptTemplate

# %%
template=ChatPromptTemplate.from_messages([
    'human','give me 5 pros on the indian cricket{input}'

])

# %%
model=Ollama(model='gemma:2b')
# Out:
# /var/folders/6h/lkrcqc7d0vj6gsp7yc3xwlbr0000gn/T/ipykernel_84448/2327555685.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   model=Ollama(model='gemma:2b')

# %%
chain=template | model

# %%
response=chain.invoke('virat kohli')
print(response)
# Out:
# **Sure, here are 5 pros on the Indian cricketer Virat Kohli:**
#
# 1. **Exceptional batting talent:** Kohli is widely regarded as one of the greatest batsmen in the history of cricket. He possesses exceptional skills with the bat, showcasing remarkable timing, technique, and consistency.
#
# 2. **Leadership and charisma:** As the captain of the Indian cricket team, Kohli is highly respected and admired for his leadership qualities and charismatic personality. He inspires his teammates with his dedication and work ethic.
#
# 3. **Consistency and reliability:** Kohli is known for his incredible consistency in scoring runs. He averages consistently in test matches and is a consistent performer in limited-overs formats as well.
#
# 4. **Versatile batting style:** Kohli is a versatile player who can adapt his style of play depending on the situation. He is a left-handed batsman who can score runs with both the bat and his gloves.
#
# 5. **International success:** Kohli has consistently performed for India in international tournaments, including four ICC World Cups, four ICC T20 World Cups, and three Cricket World Cups. He has also been a key member of the Indian team in Test matches, ODIs, and T20Is.

# %%
from langchain_core.runnables import RunnableSequence
chain = RunnableSequence(template, model)
chain.get_graph().print_ascii()
# Out:
#     +-------------+
#     | PromptInput |
#     +-------------+
#            *
#            *
#            *
# +--------------------+
# | ChatPromptTemplate |
# +--------------------+
#            *
#            *
#            *
#       +--------+
#       | Ollama |
#       +--------+
#            *
#            *
#            *
#    +--------------+
#    | OllamaOutput |
#    +--------------+
